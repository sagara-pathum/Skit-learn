# %% [markdown]
# <a href="https://colab.research.google.com/github/sagara-pathum/Skit-learn/blob/main/example_Impact_of_Ai_on_Students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# somethime we get warning when we donwload the dataset , saying that kaggle version is old.
# so first of all upgrade the version

# !pip install --upgrade kaggle

# %%
# you will need to download the kaggle api from your account. just go to kaggle  settings -> account -> tokens -> create api key
# it will download a kaggle.json file. you need to upload it to the project
# to upload items we can use googles file library. it is provided by google colab. then use upload() function to upload the file

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6006e792-e386-4047-b738-879d97e27e2d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6006e792-e386-4047-b738-879d97e27e2d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# your file is uploaded to the root of your colab.
# dont put it their
# make a hidden kaggle folder if not exist. then copy the file to that folder
# give the read write permission to the user

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# now your connection is ok . now you can download the dataset from kaggle.
# command id 'kaggle datasets download -d <providers-username>/<dataset-name>
# this will download the zip file from kaggle to your colab project

# !kaggle datasets download -d laveshjadon/ai-impact-on-students
# Out:
# Dataset URL: https://www.kaggle.com/datasets/laveshjadon/ai-impact-on-students
# License(s): CC0-1.0
# ai-impact-on-students.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# unzip the downloaded file and use

# !unzip ai-impact-on-students.zip
# Out:
# Archive:  ai-impact-on-students.zip
# replace ai_student_impact_dataset (1).csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ai_student_impact_dataset (1).csv

# %%
# to read the data better and making data frames i use pandas. so import it
# also i need to try a ml model so add scikit learn

import pandas as pd
import sklearn

# %%
# using pandas we can read a csv file as a data fram using pands function of 'read_csv' . just assign a variable to it so that it can use when we need

df = pd.read_csv('ai_student_impact_dataset (1).csv')

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
# we can take subset of data frame , using <dataframe>.drop() inside it we need to specify a list of columns we need to drop

X = df.drop(columns=['Burnout_Risk_Level'])
X.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
# another way is makeing subset is : specifying what 'intiger locations' we need in each rows and columns of the dataframe

X1 = df.iloc[:,:-1]  # here : define the range. the format is [rows,columns]. if we define numbers in -(minus) means exept tha number
X1.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
## lets just take the features for calculations

X2 = df.iloc[:,1:15]
X2.head()
# Out:
#   Major_Category Year_of_Study  Pre_Semester_GPA  Weekly_GenAI_Hours  \
# 0     Humanities        Senior             2.418               23.31
# 1        Medical        Junior             3.821                1.12
# 2       Business      Freshman             3.398               21.26
# 3       Business        Senior             3.789                1.82
# 4           STEM     Sophomore             3.635                9.29
#
#             Primary_Use_Case Prompt_Engineering_Skill  Tool_Diversity  \
# 0       Copywriting/Drafting                 Beginner               1
# 1                   Ideation                 Advanced               5
# 2        Summarizing_Reading                 Beginner               2
# 3       Copywriting/Drafting             Intermediate               4
# 4  Debugging/Troubleshooting                 Advanced               4
#
#    Paid_Subscription  Traditional_Study_Hours  Perceived_AI_Dependency  \
# ...
